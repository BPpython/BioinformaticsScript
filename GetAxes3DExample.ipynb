# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook
x,y,z = np.random.randn(3,100)
fig = plt.figure() # https://blog.csdn.net/m0_37362454/article/details/81511427
ax = fig.gca(projection = "3d") 
sc = ax.scatter(x,y,z,c = np.random.randn(100))
plt.colorbar(sc)
# Out:
# <img src="data:image/png;base64,..." width="640">
